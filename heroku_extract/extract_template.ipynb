# %%
################
### If first time import into google sheet ; run this first part of the code
### 

import os
import psycopg2
import pandas as pd
from pandas import DataFrame
import pandasql
import pygsheets
from datetime import date,datetime, timedelta
from pyparsing import col
import pytz

try:
    connection = psycopg2.connect(database="da1skpd3lipdeg",
                            host="ec2-3-219-2-230.compute-1.amazonaws.com",
                            port=5432, 
                            user="arnaldo",
                            password="p2c76731ad9767e75b20a5a77f21b3d42ba65f705161d3a9b3096006bdf97d0fb")
    cursor = connection.cursor()
    cursor_query = '''SELECT * from merchants'''
    cursor.execute(cursor_query)
    # df_SKU_staging = DataFrame(cursor.fetchall())
    df_db = cursor.fetchall()
    cols = []
    for elt in cursor.description:
        cols.append(elt[0])
    df = pd.DataFrame(data=df_db,columns=cols)
    print("Total rows are:  ", len(df_db))

    
except (Exception, psycopg2.Error) as error:
    print("Error while fetching data from PostgreSQL", error)

finally:
    # closing database connection.
    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# Total rows are:   9660
# PostgreSQL connection is closed

# %%
df
# Out:
#                                merchant_id    phone_number  \
# 0     124059af-2d56-4c3c-af96-4f1a855ddca2  +6281232233231
# 1     a34ee81c-be50-4076-bfc1-4f3f1c430d63  +6285217502646
# 2     69d19cc5-b4b2-4053-997e-2715adf29392  +6287849725499
# 3     cf97556c-2849-4dbe-b544-645b888da75f  +6285707172755
# 4     73d34b3a-ce12-4eb9-a5f0-544b5486d345  +6285231757558
# ...                                    ...             ...
# 9655  115849ab-1d5c-44ee-9221-30d2debc8141  +6282291338799
# 9656  1ede1193-88f8-4e77-9667-d200582587df  +6287741476674
# 9657  0a75c974-feaf-4395-ba0e-4c93e2bb9937  +6285730105508
# 9658  c1284f70-8799-4a13-9c39-4c11f735b6be  +6283138071501
# 9659  63990270-5b63-4eb6-99f0-b5eb053b5aa1  +6283869355935
#
#              merchant_name   poc address  latitude   longitude location_type  \
# 0                     None  None    None       NaN         NaN          None
# 1                     None  None    None       NaN         NaN          None
# ...
